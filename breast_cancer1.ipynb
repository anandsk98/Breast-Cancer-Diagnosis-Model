# %% [markdown]
# <a href="https://colab.research.google.com/github/anandsk98/Breast-Cancer-Diagnosis-Model/blob/main/breast_cancer1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e3457701-f8e7-4e35-a05d-87f0f33d2c02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3457701-f8e7-4e35-a05d-87f0f33d2c02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Breast Cancer Data (1).csv to Breast Cancer Data (1).csv

# %%
df=pd.read_csv('Breast Cancer Data (1).csv')
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df = df.drop(['Unnamed: 32'], axis = 1)
df
# Out:
#            id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302         M  ...          0.4601                  0.11890
# 1      842517         M  ...          0.2750                  0.08902
# 2    84300903         M  ...          0.3613                  0.08758
# 3    84348301         M  ...          0.6638                  0.17300
# 4    84358402         M  ...          0.2364                  0.07678
# ..        ...       ...  ...             ...                      ...
# 564    926424         M  ...          0.2060                  0.07115
# 565    926682         M  ...          0.2572                  0.06637
# 566    926954         M  ...          0.2218                  0.07820
# 567    927241         M  ...          0.4087                  0.12400
# 568     92751         B  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
df = df.drop(['id'], axis = 1)
df
# Out:
#     diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0           M        17.99  ...          0.4601                  0.11890
# 1           M        20.57  ...          0.2750                  0.08902
# 2           M        19.69  ...          0.3613                  0.08758
# 3           M        11.42  ...          0.6638                  0.17300
# 4           M        20.29  ...          0.2364                  0.07678
# ..        ...          ...  ...             ...                      ...
# 564         M        21.56  ...          0.2060                  0.07115
# 565         M        20.13  ...          0.2572                  0.06637
# 566         M        16.60  ...          0.2218                  0.07820
# 567         M        20.60  ...          0.4087                  0.12400
# 568         B         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
#label encoding
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()

df['diagnosis']=label_encoder.fit_transform(df['diagnosis'])
df
# Out:
#      diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0            1        17.99  ...          0.4601                  0.11890
# 1            1        20.57  ...          0.2750                  0.08902
# 2            1        19.69  ...          0.3613                  0.08758
# 3            1        11.42  ...          0.6638                  0.17300
# 4            1        20.29  ...          0.2364                  0.07678
# ..         ...          ...  ...             ...                      ...
# 564          1        21.56  ...          0.2060                  0.07115
# 565          1        20.13  ...          0.2572                  0.06637
# 566          1        16.60  ...          0.2218                  0.07820
# 567          1        20.60  ...          0.4087                  0.12400
# 568          0         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
plt.figure(figsize = (16, 16))
sns.heatmap(df.corr(),annot=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
x=df[['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']]
y=df['diagnosis']

print(x.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 30)

print(x_train.shape)
print(x_test.shape)
# Out:
# (455, 30)
# (114, 30)

# %%
from sklearn.preprocessing import StandardScaler

# creating a standard scaler
sc = StandardScaler()

# feeding independents sets into the standard scaler
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)
print(x_train)
print(x_test)
# Out:
# [[ 4.14421628e+00  6.60424390e-01]
#  [-1.46156208e+00  2.49932535e-01]
#  [ 3.12093071e+00  1.44926729e+00]
#  [-1.05476506e+00 -3.31627044e+00]
#  [-4.08041914e+00 -1.36628271e+00]
#  [-1.46232635e+00 -1.59844855e-01]
#  [ 3.19660029e+00  3.29306853e+00]
#  [-2.17857929e+00  1.55016797e+00]
#  [-2.20963390e+00  1.10331638e-01]
#  [-8.89406176e-01  1.82018488e+00]
#  [-8.08425015e-01  3.12816841e+00]
#  [-3.84519969e+00  4.28985818e+00]
#  [-4.12920791e-01 -8.29083173e-01]
#  [-2.31320083e+00 -2.17920235e-02]
#  [ 2.69411601e-01  1.60567566e-01]
#  [ 6.82539916e+00  1.24530975e+01]
#  [-2.77350842e+00 -1.75470216e+00]
#  [ 9.02369321e+00  1.82602565e+00]
#  [ 2.77895305e+00 -1.16540574e+00]
#  [-2.23774318e+00  1.24895693e+00]
#  [-2.84471077e+00 -1.01818227e+00]
#  [-4.70772950e+00 -2.37380236e-01]
#  [ 1.94948541e+00  6.41031449e+00]
#  [-2.14697497e+00  1.86502688e+00]
#  [ 1.65238141e+00 -2.14911828e+00]
#  [-1.64934918e+00  1.70194649e+00]
#  [-2.02959754e+00 -2.28580884e-01]
# ...

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf=RandomForestClassifier()
rf.fit(x_train,y_train)

predictions=rf.predict(x_test)
print(accuracy_score(y_test,predictions))
# Out:
# 0.9122807017543859

# %%
#SVM
from sklearn.svm import SVC

model=SVC()
model.fit(x_train,y_train)

pred=model.predict(x_test)
print(accuracy_score(y_test,pred))
# Out:
# 0.9210526315789473

# %%
#logistic regression

from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train,y_train)

pred=logreg.predict(x_test)
print(accuracy_score(y_test,pred))
# Out:
# 0.9210526315789473

# %%
#KNN

from sklearn.neighbors import KNeighborsClassifier

modelknn=KNeighborsClassifier()
modelknn.fit(x_train,y_train)

pred=modelknn.predict(x_test)
print(accuracy_score(y_test,pred))
# Out:
# 0.9122807017543859

# %%
#naive bayes
from sklearn.naive_bayes import GaussianNB

model=GaussianNB()
model.fit(x_train,y_train)

pred=model.predict(x_test)
print(accuracy_score(y_test,pred))
# Out:
# 0.8947368421052632

# %%
#XG Boosting
from xgboost import XGBClassifier

model=XGBClassifier()
model.fit(x_train,y_train)

pred=model.predict(x_test)
print(accuracy_score(y_test,pred))
# Out:
# 0.9210526315789473
